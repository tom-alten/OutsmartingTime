# %% [markdown]
# ## Config

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data

# %%
path_to_year = '/Users/tomaltenborg/Documents/Master/Master thesis/Notebooks/M-Competitions/M3-Competition/Year/M3_yearly_results.parquet'
path_to_quarter = '/Users/tomaltenborg/Documents/Master/Master thesis/Notebooks/M-Competitions/M3-Competition/Quarter/M3_quarter_results.parquet'
path_to_month = '/Users/tomaltenborg/Documents/Master/Master thesis/Notebooks/M-Competitions/M3-Competition/Month/M3_monthly_results.parquet'

df_year = pd.read_parquet(path_to_year)
df_quarter = pd.read_parquet(path_to_quarter)
df_month = pd.read_parquet(path_to_month)

df = pd.concat([df_year, df_quarter, df_month])
df = df.reset_index(drop=True)
df.sort_values(by = ['Series', 'ForecastPeriod', 'Method'], inplace = True)
df['Category'] = df['Category'].str.strip()

# %%
print(df.Series.max())
# Out:
# 2829

# %%
methods = ['ARARMA', 'Auto-ANN', 'AutoBox1', 'B-J auto',
 'COMB S-H-D', 'DAMPEN', 'Flors-Pearc1', 'ForcX', 'ForecastPro',
 'HOLT', 'NAIVE2', 'PP-Autocast', 'RBF', 'ROBUST-Trend', 'SINGLE', 'SMARTFCS',
 'THETA', 'TimeGPT', 'WINTER', 'AAM1']

# %% [markdown]
# # Yearly data by category

# %%
year_df = df.loc[df['Series'] <= 645].copy()

# %%
cat_list = year_df['Category'].unique().tolist()
print(cat_list)
# Out:
# ['MICRO', 'INDUSTRY', 'MACRO', 'FINANCE', 'DEMOGRAPHIC', 'OTHER']

# %%
micro_df = year_df.loc[year_df['Category'] == 'MICRO'].copy()

# %% [markdown]
# ## MICRO

# %% [markdown]
# ### sMAPE

# %%
filtered_df = micro_df[micro_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Yearly Micro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = micro_df[micro_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Yearly Micro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = micro_df[micro_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Yearly Micro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## MACRO

# %%
macro_df = year_df.loc[year_df['Category'] == 'MACRO'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = macro_df[macro_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Yearly Macro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = macro_df[macro_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Yearly Macro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = macro_df[macro_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Yearly Macro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## INDUSTRY

# %%
industry_df = year_df.loc[year_df['Category'] == 'INDUSTRY'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = industry_df[industry_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Yearly Industry Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = industry_df[industry_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean RMSE Yearly Industry Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = industry_df[industry_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean MDRAE Yearly Industry Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## Finance

# %%
finance_df = year_df.loc[year_df['Category'] == 'FINANCE'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = finance_df[finance_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Yearly Finance Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = finance_df[finance_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Yearly Finance Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = finance_df[finance_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Yearly Finance Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## DEMOGRAPHIC

# %%
demographic_df = year_df.loc[year_df['Category'] == 'DEMOGRAPHIC'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = demographic_df[demographic_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Yearly Demographic Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = demographic_df[demographic_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Yearly Demographic Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = demographic_df[demographic_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Yearly Demographic Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## OTHER

# %%
other_df = year_df.loc[year_df['Category'] == 'OTHER'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = other_df[other_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Yearly Other Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = other_df[other_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Yearly Other Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = other_df[other_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Yearly Other Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# # Quarterly Data By Category

# %%
quarter_df = df.loc[(df['Series'] > 645) & (df['Series'] <= 1401)].copy()

# %%
print(quarter_df['Category'].unique())
# Out:
# ['MICRO' 'INDUSTRY' 'MACRO' 'FINANCE' 'DEMOGRAPHIC']

# %% [markdown]
# ## MICRO

# %%
micro_df = quarter_df.loc[quarter_df['Category'] == 'MICRO'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = micro_df[micro_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Quarter Micro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = micro_df[micro_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Quarter Micro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = micro_df[micro_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Quarter Micro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## MACRO

# %%
macro_df = quarter_df.loc[quarter_df['Category'] == 'MACRO'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = macro_df[macro_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Quarter Macro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = macro_df[macro_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Quarter Macro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = macro_df[macro_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Quarter Macro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## INDUSTRY

# %%
industry_df = quarter_df.loc[quarter_df['Category'] == 'INDUSTRY'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = industry_df[industry_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Quarter Industry Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = industry_df[industry_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Quarter Industry Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = industry_df[industry_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Quarter Industry Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## Finance

# %%
finance_df = quarter_df.loc[quarter_df['Category'] == 'FINANCE'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = finance_df[finance_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Quarterly Finance Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = finance_df[finance_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Quarterly Finance Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = finance_df[finance_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Quarterly Finance Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## DEMOGRAPHIC

# %%
demographic_df = quarter_df.loc[quarter_df['Category'] == 'DEMOGRAPHIC'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = demographic_df[demographic_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Quarterly Demographic Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = demographic_df[demographic_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Quarterly Demographic Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = demographic_df[demographic_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Quarterly Demographic Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# # Monthly Data Per Category

# %%
month_df = df.loc[df['Series'] > 1401].copy()

# %%
print(month_df['Category'].unique())
# Out:
# ['MICRO' 'INDUSTRY' 'MACRO' 'FINANCE' 'DEMOGRAPHIC' 'OTHER']

# %% [markdown]
# ## MICRO

# %%
micro_df = month_df.loc[month_df['Category'] == 'MICRO'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = micro_df[micro_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Month Micro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = micro_df[micro_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Month Micro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = micro_df[micro_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Month Micro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## MACRO

# %%
macro_df = month_df.loc[month_df['Category'] == 'MACRO'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = macro_df[macro_df['Method'].isin(methods)]

# Calculate mean of SMAPE per unique Method
mean_SMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_SMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_SMAPE_per_method.index])
plt.title('Mean SMAPE Month Macro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean SMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_SMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = macro_df[macro_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Month Macro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = macro_df[macro_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Month Macro Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## INDUSTRY

# %%
industry_df = month_df.loc[month_df['Category'] == 'INDUSTRY'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = industry_df[industry_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Monthly Industry Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = industry_df[industry_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Monthly Industry Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = industry_df[industry_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Monthly Industry Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## Finance

# %%
finance_df = month_df.loc[month_df['Category'] == 'FINANCE'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = finance_df[finance_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Monthly Finance Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = finance_df[finance_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Monthly Finance Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = finance_df[finance_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Monthly Finance Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## DEMOGRAPHIC

# %%
demographic_df = month_df.loc[month_df['Category'] == 'DEMOGRAPHIC'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = demographic_df[demographic_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Monthly Demographic Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = demographic_df[demographic_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Monthly Demographic Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = demographic_df[demographic_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Monthly Demographic Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ## OTHER

# %%
other_df = month_df.loc[month_df['Category'] == 'OTHER'].copy()

# %% [markdown]
# ### sMAPE

# %%
filtered_df = other_df[other_df['Method'].isin(methods)]

# Calculate mean of sMAPE per unique Method
mean_sMAPE_per_method = filtered_df.groupby('Method')['sMAPE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_sMAPE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_sMAPE_per_method.index])
plt.title('Mean sMAPE Monthly Other Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean sMAPE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_sMAPE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### RMSE

# %%
filtered_df = other_df[other_df['Method'].isin(methods)]

# Calculate mean of RMSE per unique Method
mean_RMSE_per_method = filtered_df.groupby('Method')['RMSE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_RMSE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_RMSE_per_method.index])
plt.title('Mean RMSE Monthly Other Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean RMSE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_RMSE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()

# %% [markdown]
# ### MdRAE

# %%
filtered_df = other_df[other_df['Method'].isin(methods)]

# Calculate mean of MDRAE per unique Method
mean_MDRAE_per_method = filtered_df.groupby('Method')['MDRAE'].mean().sort_values()

# Plot
plt.figure(figsize=(12, 8))  # Set figure size
bars = mean_MDRAE_per_method.plot(kind='bar', color=['blue' if method != 'TimeGPT' else 'red' for method in mean_MDRAE_per_method.index])
plt.title('Mean MDRAE Monthly Other Data', fontsize = 16, fontweight = 'bold')  # Title of the chart
plt.ylabel('Mean MDRAE', fontsize = 12)  # Y-axis label
plt.xlabel('Method', fontsize = 12)  # X-axis label
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels and align them to the right for better readability
plt.tight_layout()  # Adjust layout to make sure everything fits without overlapping

# Customize colors
for method, bar in zip(mean_MDRAE_per_method.index, bars.patches):
    bar.set_color('red' if method == 'TimeGPT' else 'blue')

plt.show()
