# %% [markdown]
# ## Config

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data

# %%
df = pd.read_excel('M3C.xls', sheet_name='M3Quart')
df.head()
# Out:
#   Series   N  NF      Category  Starting Year  Starting Quarter        1  \
# 0  N 646  44   8  MICRO                  1984                 1  3142.63
# 1  N 647  44   8  MICRO                  1984                 1  1522.00
# 2  N 648  46   8  MICRO                  1983                 3  1549.72
# 3  N 649  44   8  MICRO                  1984                 1  2182.60
# 4  N 650  44   8  MICRO                  1984                 1   875.51
#
#          2        3        4  ...  63  64  65  66  67  68  69  70  71  72
# 0  3190.75  3178.69  3170.94  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1  1537.80  1602.60  1697.00  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2  1615.08  1620.33  1634.41  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3  2189.80  2136.70  2155.60  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4   917.23   999.89  1014.70  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 78 columns]

# %%
df['Series'] = df['Series'].str.replace('N ', '')
df['Series'] = df['Series'].str.replace('N', '').astype(int)

# %% [markdown]
# ## Melt from wide format to long format

# %%
# Using pandas.melt to transform the DataFrame
melted_df = pd.melt(df, id_vars=['Series', 'N', 'NF', 'Category', 'Starting Year', 'Starting Quarter'], 
                    var_name='Measurement', value_name='Value')

# %%
melted_df = melted_df.sort_values(by=['Series', 'Category'])

# %% [markdown]
# NB! Change one data flaw that says that one the series has starting quarter equal to 9, fix this mistake

# %%
melted_df['Starting Quarter'] = melted_df['Starting Quarter'].replace(9, 1)

# %%
## Do rstrip in the cateogry column
melted_df['Category'] = melted_df['Category'].str.rstrip()
print(melted_df['Category'].unique())
# Out:
# ['MICRO' 'INDUSTRY' 'MACRO' 'FINANCE' 'DEMOGRAPHIC']

# %%
melted_df.dropna(subset=['Value'], inplace=True)
melted_df.reset_index(drop=True, inplace=True)

# %%
melted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37004 entries, 0 to 37003
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series            37004 non-null  int64
#  1   N                 37004 non-null  int64
#  2   NF                37004 non-null  int64
#  3   Category          37004 non-null  object
#  4   Starting Year     37004 non-null  int64
#  5   Starting Quarter  37004 non-null  int64
#  6   Measurement       37004 non-null  object
#  7   Value             37004 non-null  float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.3+ MB

# %%
melted_df
# Out:
#        Series   N  NF     Category  Starting Year  Starting Quarter  \
# 0         646  44   8        MICRO           1984                 1
# 1         646  44   8        MICRO           1984                 1
# 2         646  44   8        MICRO           1984                 1
# 3         646  44   8        MICRO           1984                 1
# 4         646  44   8        MICRO           1984                 1
# ...       ...  ..  ..          ...            ...               ...
# 36999    1401  48   8  DEMOGRAPHIC           1964                 1
# 37000    1401  48   8  DEMOGRAPHIC           1964                 1
# 37001    1401  48   8  DEMOGRAPHIC           1964                 1
# 37002    1401  48   8  DEMOGRAPHIC           1964                 1
# 37003    1401  48   8  DEMOGRAPHIC           1964                 1
#
#       Measurement    Value
# 0               1  3142.63
# 1               2  3190.75
# 2               3  3178.69
# 3               4  3170.94
# 4               5  3124.38
# ...           ...      ...
# 36999          44  2490.00
# 37000          45  2070.00
# 37001          46  2000.00
# 37002          47  1650.00
# 37003          48  1650.00
#
# [37004 rows x 8 columns]

# %% [markdown]
# ## Add a datetime column

# %%
# Calculate the actual year and quarter, considering the 'Measurement' as the quarter offset
# First, calculate the total quarters from the starting point
total_quarters = (melted_df['Starting Year'] - 1) * 4 + melted_df['Starting Quarter'] + melted_df['Measurement'] - 1

# Calculate the actual year and quarter
actual_year = (total_quarters - 1) // 4 + 1
actual_quarter = (total_quarters - 1) % 4 + 1

# Map the actual quarter to the corresponding starting month of each quarter
month_map = {1: '01', 2: '04', 3: '07', 4: '10'}
actual_month = actual_quarter.map(month_map)

# Now, create the datetime column with the correct year, month, and fixed day (01)
melted_df['Date'] = pd.to_datetime(actual_year.astype(str) + '-' + actual_month + '-01')

melted_df.head()
# Out:
#    Series   N  NF Category  Starting Year  Starting Quarter Measurement  \
# 0     646  44   8    MICRO           1984                 1           1
# 1     646  44   8    MICRO           1984                 1           2
# 2     646  44   8    MICRO           1984                 1           3
# 3     646  44   8    MICRO           1984                 1           4
# 4     646  44   8    MICRO           1984                 1           5
#
#      Value       Date
# 0  3142.63 1984-01-01
# 1  3190.75 1984-04-01
# 2  3178.69 1984-07-01
# 3  3170.94 1984-10-01
# 4  3124.38 1985-01-01

# %%
melted_df.drop(columns = ['Starting Year','Starting Quarter'], inplace = True)

# %%
melted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37004 entries, 0 to 37003
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Series       37004 non-null  int64
#  1   N            37004 non-null  int64
#  2   NF           37004 non-null  int64
#  3   Category     37004 non-null  object
#  4   Measurement  37004 non-null  object
#  5   Value        37004 non-null  float64
#  6   Date         37004 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 2.0+ MB

# %%
melted_df.loc[melted_df['Series'] == 764]
# Out:
#       Series   N  NF Category Measurement    Value       Date
# 5202     764  44   8    MICRO           1  2711.10 1984-01-01
# 5203     764  44   8    MICRO           2  2933.95 1984-04-01
# 5204     764  44   8    MICRO           3  3046.80 1984-07-01
# 5205     764  44   8    MICRO           4  3294.80 1984-10-01
# 5206     764  44   8    MICRO           5  3141.15 1985-01-01
# 5207     764  44   8    MICRO           6  3306.25 1985-04-01
# 5208     764  44   8    MICRO           7  3373.35 1985-07-01
# 5209     764  44   8    MICRO           8  4037.60 1985-10-01
# 5210     764  44   8    MICRO           9  3758.95 1986-01-01
# 5211     764  44   8    MICRO          10  3833.00 1986-04-01
# 5212     764  44   8    MICRO          11  3850.30 1986-07-01
# 5213     764  44   8    MICRO          12  4125.25 1986-10-01
# 5214     764  44   8    MICRO          13  4631.20 1987-01-01
# 5215     764  44   8    MICRO          14  4602.90 1987-04-01
# 5216     764  44   8    MICRO          15  4603.95 1987-07-01
# 5217     764  44   8    MICRO          16  5104.45 1987-10-01
# 5218     764  44   8    MICRO          17  5047.25 1988-01-01
# 5219     764  44   8    MICRO          18  5295.90 1988-04-01
# 5220     764  44   8    MICRO          19  5331.50 1988-07-01
# 5221     764  44   8    MICRO          20  5662.25 1988-10-01
# 5222     764  44   8    MICRO          21  5298.90 1989-01-01
# 5223     764  44   8    MICRO          22  5287.85 1989-04-01
# 5224     764  44   8    MICRO          23  5212.10 1989-07-01
# 5225     764  44   8    MICRO          24  5810.15 1989-10-01
# 5226     764  44   8    MICRO          25  5750.20 1990-01-01
# 5227     764  44   8    MICRO          26  5980.15 1990-04-01
# 5228     764  44   8    MICRO          27  5797.90 1990-07-01
# 5229     764  44   8    MICRO          28  6560.25 1990-10-01
# 5230     764  44   8    MICRO          29  5612.90 1991-01-01
# 5231     764  44   8    MICRO          30  5838.85 1991-04-01
# 5232     764  44   8    MICRO          31  5506.95 1991-07-01
# 5233     764  44   8    MICRO          32  6296.30 1991-10-01
# 5234     764  44   8    MICRO          33  5542.15 1992-01-01
# 5235     764  44   8    MICRO          34  5818.60 1992-04-01
# 5236     764  44   8    MICRO          35  5952.10 1992-07-01
# 5237     764  44   8    MICRO          36  6440.70 1992-10-01
# 5238     764  44   8    MICRO          37  5357.05 1993-01-01
# 5239     764  44   8    MICRO          38  5807.90 1993-04-01
# 5240     764  44   8    MICRO          39  5789.75 1993-07-01
# 5241     764  44   8    MICRO          40  6597.30 1993-10-01
# 5242     764  44   8    MICRO          41  5496.10 1994-01-01
# 5243     764  44   8    MICRO          42  5923.50 1994-04-01
# 5244     764  44   8    MICRO          43  6016.80 1994-07-01
# 5245     764  44   8    MICRO          44  7042.10 1994-10-01

# %%
melted_df.to_parquet('M3_quarter_processed.parquet', index=False, compression='snappy', engine='pyarrow')
